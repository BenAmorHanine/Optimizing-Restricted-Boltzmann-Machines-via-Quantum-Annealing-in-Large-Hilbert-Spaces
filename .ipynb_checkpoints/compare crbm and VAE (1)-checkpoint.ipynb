# %% [markdown]
# ## CRBM

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from time import time

from crbm.rbm import CRBM
# Import our RBM
from crbm.rbm import CRBM

# %%
# Function for reading data file
import struct
def read_idx(filename):
    with open(filename, 'rb') as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.frombuffer(f.read(), dtype=np.uint8).reshape(shape)

# %%
X_test = read_idx("data/MNIST/raw/t10k-images-idx3-ubyte").reshape(-1, 28*28)
X = read_idx("data/MNIST/raw/train-images-idx3-ubyte").reshape(-1, 28*28)
y_test = read_idx("data/MNIST/raw/t10k-labels-idx1-ubyte")
y = read_idx("data/MNIST/raw/train-labels-idx1-ubyte")

# EXTREMELY IMPORTANT TO NORMALIZE
X = np.true_divide(X, 255)
X_test = np.true_divide(X_test, 255)

# %%
# Some hand picked images for each class for plotting
selected_imgs = X[[1, 6, 5, 12, 26, 35, 62, 52, 46, 4]]

# %%
# Train-val split
split = 0.1
indices = np.arange(len(X))
np.random.shuffle(indices)
X_val = X[:int(split*X.shape[0])]
X_train = X[int(split*X.shape[0]):]
y_val = y[:int(split*X.shape[0])]
y_train = y[int(split*X.shape[0]):]
print("Number of training instances:\t", y_train.shape[0])
print("Number of validation instances:\t", y_val.shape[0])
print("Number of test instances:\t", y_test.shape[0])
# Out:
# Number of training instances:	 54000
# Number of validation instances:	 6000
# Number of test instances:	 10000

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Number of training instances:\t", y_train.shape[0])
print("Number of validation instances:\t", y_val.shape[0])
print("Number of test instances:\t", y_test.shape[0])
# Out:
# Number of training instances:	 54000
# Number of validation instances:	 6000
# Number of test instances:	 10000

# %%
def KL(P, Q):
    epsilon = 1e-10
    P = np.clip(P, epsilon, 1)
    Q = np.clip(Q, epsilon, 1)
    return np.sum(P * np.log(P / Q))

# %%
def get_batches(data, batch_size, shuffle=False):
    '''
    Function to provide data in batches.
    input:
        - data: The data to be batched, each sample in one row.
        - batch_size: Size of one batch (last batch might be smaller)
        - shuffle: True if data should be shuffled.
    '''
    if(shuffle):
        np.random.shuffle(data)
    if(batch_size == -1):
        batch_size = len(data)
    num_batches = math.ceil(data.shape[0]/batch_size)
    for batch_num in range(num_batches):
        yield data[batch_num*batch_size:(batch_num+1)*batch_size]

# %%
# Some parameters to set
batch_size = 50
num_epochs = 100
lr = 0.1
burn_in = 0
num_steps = 1

# %%
model = CRBM(v_dim=X_train.shape[-1], h_dim=100)

# %%
crbm_dkl_per_epoch = []

# %%
from time import time
import torch
# Training loop
errors = []
free_energies_val = []
free_energies_train = []
start_time = time()

for epoch in range(1, num_epochs+1):
    iteration = 0
    error = 0
    for batch in get_batches(X_train, batch_size, shuffle=True):
        iteration += 1
   
        # Compute gradients and errors
        error += model.compute_grad(batch)
        
        # Update parameters - use momentum as explained in Hinton's guide
        if(epoch > 5):
            model.update(lr, momentum=0.5)
        else:
            model.update(lr, momentum=0.9)
        
    #plot_images(rbm, selected_imgs, 
    #        title="Reconstructed Images    Epoch: {}".format(epoch),
    #        save_as="recon_" + str(epoch))
        
    print("epoch:{} \t error:{:.4f} \t training time:{:.2f} s".format(epoch, error, time()-start_time))
    errors.append(error)
    # Calcul du DKL sur 100 images de validation
    
    # == Calcule DKL pour le CRBM à chaque époque ==
    dkl_values = []
    num_samples = 10  # ou plus selon les ressources
    
    with torch.no_grad():
        for i in range(num_samples):
            img = X_val[i].reshape(-1)  # Assure-toi que X_val est bien défini
            img_resized = img.reshape(28, 28).flatten()

    
            # Normalisation
            img_rescaled = img_resized / np.max(img_resized) if np.max(img_resized) > 0 else img_resized
            recon = model.get_reconstruction(img_rescaled)
    
            # Empêche division par zéro
            P = recon / np.sum(recon) if np.sum(recon) > 0 else np.ones_like(recon) / len(recon)
            Q = img_rescaled / np.sum(img_rescaled) if np.sum(img_rescaled) > 0 else np.ones_like(img_rescaled) / len(img_rescaled)
    
            dkl = KL(P, Q)
            dkl_values.append(dkl)
    
    mean_dkl = np.mean(dkl_values)
    crbm_dkl_per_epoch.append(mean_dkl)
    print(f"Epoch {epoch} - Mean DKL: {mean_dkl:.4f}")
# Out:
# epoch:1 	 error:28177.9488 	 training time:17.14 s
# Epoch 1 - Mean DKL: 1.7572
# epoch:2 	 error:16284.3392 	 training time:35.55 s
# Epoch 2 - Mean DKL: 1.4514
# epoch:3 	 error:14843.4112 	 training time:52.60 s
# Epoch 3 - Mean DKL: 1.3615
# epoch:4 	 error:14124.3962 	 training time:69.96 s
# Epoch 4 - Mean DKL: 1.2778
# epoch:5 	 error:13686.9106 	 training time:86.58 s
# Epoch 5 - Mean DKL: 1.2598
# epoch:6 	 error:13399.7389 	 training time:104.12 s
# Epoch 6 - Mean DKL: 1.2232
# epoch:7 	 error:13177.0996 	 training time:122.13 s
# Epoch 7 - Mean DKL: 1.1819
# epoch:8 	 error:13013.9229 	 training time:140.23 s
# Epoch 8 - Mean DKL: 1.1256
# epoch:9 	 error:12869.0481 	 training time:157.79 s
# Epoch 9 - Mean DKL: 1.1133
# epoch:10 	 error:12751.5492 	 training time:175.85 s
# Epoch 10 - Mean DKL: 1.0825
# epoch:11 	 error:12645.9967 	 training time:193.84 s
# Epoch 11 - Mean DKL: 1.0532
# epoch:12 	 error:12546.1780 	 training time:210.72 s
# Epoch 12 - Mean DKL: 1.0354
# epoch:13 	 error:12465.3201 	 training time:228.01 s
# Epoch 13 - Mean DKL: 1.0242
# epoch:14 	 error:12397.6342 	 training time:246.49 s
# Epoch 14 - Mean DKL: 0.9878
# epoch:15 	 error:12326.7328 	 training time:264.05 s
# Epoch 15 - Mean DKL: 0.9695
# epoch:16 	 error:12263.4019 	 training time:282.24 s
# Epoch 16 - Mean DKL: 0.9483
# epoch:17 	 error:12206.5598 	 training time:300.85 s
# Epoch 17 - Mean DKL: 0.9812
# epoch:18 	 error:12161.4889 	 training time:318.72 s
# Epoch 18 - Mean DKL: 0.9148
# epoch:19 	 error:12115.6486 	 training time:337.38 s
# Epoch 19 - Mean DKL: 0.9280
# epoch:20 	 error:12061.8408 	 training time:355.26 s
# Epoch 20 - Mean DKL: 0.9129
# epoch:21 	 error:12020.2840 	 training time:372.77 s
# Epoch 21 - Mean DKL: 0.8964
# epoch:22 	 error:11988.4241 	 training time:389.46 s
# Epoch 22 - Mean DKL: 0.8879
# epoch:23 	 error:11949.2631 	 training time:406.06 s
# Epoch 23 - Mean DKL: 0.8944
# epoch:24 	 error:11925.3558 	 training time:423.08 s
# Epoch 24 - Mean DKL: 0.8785
# epoch:25 	 error:11879.5074 	 training time:439.82 s
# Epoch 25 - Mean DKL: 0.8943
# epoch:26 	 error:11858.8565 	 training time:456.34 s
# Epoch 26 - Mean DKL: 0.8921
# epoch:27 	 error:11836.7287 	 training time:472.86 s
# Epoch 27 - Mean DKL: 0.8429
# epoch:28 	 error:11808.7659 	 training time:489.55 s
# Epoch 28 - Mean DKL: 0.8727
# epoch:29 	 error:11776.3216 	 training time:506.27 s
# Epoch 29 - Mean DKL: 0.8569
# epoch:30 	 error:11755.0119 	 training time:522.85 s
# Epoch 30 - Mean DKL: 0.8334
# epoch:31 	 error:11733.7132 	 training time:539.37 s
# Epoch 31 - Mean DKL: 0.8408
# epoch:32 	 error:11714.4564 	 training time:556.16 s
# Epoch 32 - Mean DKL: 0.8453
# epoch:33 	 error:11699.0571 	 training time:572.11 s
# Epoch 33 - Mean DKL: 0.8494
# epoch:34 	 error:11680.4607 	 training time:588.52 s
# Epoch 34 - Mean DKL: 0.8662
# epoch:35 	 error:11641.6526 	 training time:605.34 s
# Epoch 35 - Mean DKL: 0.8498
# epoch:36 	 error:11616.3777 	 training time:622.21 s
# Epoch 36 - Mean DKL: 0.8529
# epoch:37 	 error:11628.7273 	 training time:638.77 s
# Epoch 37 - Mean DKL: 0.8372
# epoch:38 	 error:11607.5170 	 training time:655.31 s
# Epoch 38 - Mean DKL: 0.8350
# epoch:39 	 error:11594.4393 	 training time:671.55 s
# Epoch 39 - Mean DKL: 0.8273
# epoch:40 	 error:11570.2441 	 training time:688.51 s
# Epoch 40 - Mean DKL: 0.8509
# epoch:41 	 error:11563.5953 	 training time:705.09 s
# Epoch 41 - Mean DKL: 0.8279
# epoch:42 	 error:11540.8553 	 training time:721.59 s
# Epoch 42 - Mean DKL: 0.8162
# epoch:43 	 error:11534.4936 	 training time:738.10 s
# Epoch 43 - Mean DKL: 0.8272
# epoch:44 	 error:11521.3579 	 training time:755.02 s
# Epoch 44 - Mean DKL: 0.8534
# epoch:45 	 error:11508.4687 	 training time:771.50 s
# Epoch 45 - Mean DKL: 0.8282
# epoch:46 	 error:11500.3646 	 training time:788.02 s
# Epoch 46 - Mean DKL: 0.8251
# epoch:47 	 error:11486.0530 	 training time:804.26 s
# Epoch 47 - Mean DKL: 0.8364
# epoch:48 	 error:11485.0820 	 training time:821.11 s
# Epoch 48 - Mean DKL: 0.8221
# epoch:49 	 error:11464.5079 	 training time:837.77 s
# Epoch 49 - Mean DKL: 0.8446
# epoch:50 	 error:11467.9499 	 training time:854.12 s
# Epoch 50 - Mean DKL: 0.8244
# epoch:51 	 error:11455.8877 	 training time:870.62 s
# Epoch 51 - Mean DKL: 0.8524
# epoch:52 	 error:11452.0772 	 training time:887.50 s
# Epoch 52 - Mean DKL: 0.8204
# epoch:53 	 error:11438.5146 	 training time:904.05 s
# Epoch 53 - Mean DKL: 0.8366
# epoch:54 	 error:11437.5595 	 training time:920.59 s
# Epoch 54 - Mean DKL: 0.8495
# epoch:55 	 error:11431.2564 	 training time:936.66 s
# Epoch 55 - Mean DKL: 0.8116
# epoch:56 	 error:11413.0071 	 training time:953.68 s
# Epoch 56 - Mean DKL: 0.8737
# epoch:57 	 error:11409.0092 	 training time:970.15 s
# Epoch 57 - Mean DKL: 0.8561
# epoch:58 	 error:11409.2692 	 training time:986.72 s
# Epoch 58 - Mean DKL: 0.8411
# epoch:59 	 error:11401.2128 	 training time:1003.29 s
# Epoch 59 - Mean DKL: 0.8503
# epoch:60 	 error:11400.6220 	 training time:1020.15 s
# Epoch 60 - Mean DKL: 0.8408
# epoch:61 	 error:11393.9600 	 training time:1036.66 s
# Epoch 61 - Mean DKL: 0.8561
# epoch:62 	 error:11386.1468 	 training time:1053.18 s
# Epoch 62 - Mean DKL: 0.8691
# epoch:63 	 error:11377.9662 	 training time:1069.65 s
# Epoch 63 - Mean DKL: 0.8568
# epoch:64 	 error:11378.2919 	 training time:1086.54 s
# Epoch 64 - Mean DKL: 0.8647
# epoch:65 	 error:11365.1766 	 training time:1103.04 s
# Epoch 65 - Mean DKL: 0.8748
# epoch:66 	 error:11369.1180 	 training time:1119.61 s
# Epoch 66 - Mean DKL: 0.8605
# epoch:67 	 error:11351.9078 	 training time:1136.02 s
# Epoch 67 - Mean DKL: 0.8458
# epoch:68 	 error:11350.7210 	 training time:1153.18 s
# Epoch 68 - Mean DKL: 0.8311
# epoch:69 	 error:11356.4230 	 training time:1168.65 s
# Epoch 69 - Mean DKL: 0.8518
# epoch:70 	 error:11352.3663 	 training time:1185.58 s
# Epoch 70 - Mean DKL: 0.8568
# epoch:71 	 error:11341.4560 	 training time:1202.29 s
# Epoch 71 - Mean DKL: 0.8425
# epoch:72 	 error:11351.0613 	 training time:1220.91 s
# Epoch 72 - Mean DKL: 0.8489
# epoch:73 	 error:11328.2411 	 training time:1239.50 s
# Epoch 73 - Mean DKL: 0.8355
# epoch:74 	 error:11321.6161 	 training time:1256.58 s
# Epoch 74 - Mean DKL: 0.8220
# epoch:75 	 error:11330.9721 	 training time:1273.73 s
# Epoch 75 - Mean DKL: 0.8432
# epoch:76 	 error:11320.8729 	 training time:1282.78 s
# Epoch 76 - Mean DKL: 0.8158
# epoch:77 	 error:11326.9815 	 training time:1291.04 s
# Epoch 77 - Mean DKL: 0.8210
# epoch:78 	 error:11309.6431 	 training time:1299.24 s
# Epoch 78 - Mean DKL: 0.8056
# epoch:79 	 error:11309.8664 	 training time:1307.81 s
# Epoch 79 - Mean DKL: 0.8046
# epoch:80 	 error:11309.9920 	 training time:1316.39 s
# Epoch 80 - Mean DKL: 0.8330
# epoch:81 	 error:11299.0046 	 training time:1325.24 s
# Epoch 81 - Mean DKL: 0.7963
# epoch:82 	 error:11295.1295 	 training time:1334.43 s
# Epoch 82 - Mean DKL: 0.8015
# epoch:83 	 error:11292.6378 	 training time:1342.90 s
# Epoch 83 - Mean DKL: 0.8144
# epoch:84 	 error:11299.5131 	 training time:1351.76 s
# Epoch 84 - Mean DKL: 0.7919
# epoch:85 	 error:11284.7203 	 training time:1360.24 s
# Epoch 85 - Mean DKL: 0.8122
# epoch:86 	 error:11289.0197 	 training time:1368.70 s
# Epoch 86 - Mean DKL: 0.8194
# epoch:87 	 error:11285.2953 	 training time:1377.83 s
# Epoch 87 - Mean DKL: 0.7875
# epoch:88 	 error:11277.8340 	 training time:1386.26 s
# Epoch 88 - Mean DKL: 0.7902
# epoch:89 	 error:11271.9666 	 training time:1394.81 s
# Epoch 89 - Mean DKL: 0.8022
# epoch:90 	 error:11268.1102 	 training time:1403.64 s
# Epoch 90 - Mean DKL: 0.7955
# epoch:91 	 error:11254.9399 	 training time:1412.42 s
# Epoch 91 - Mean DKL: 0.7974
# epoch:92 	 error:11248.8077 	 training time:1420.92 s
# Epoch 92 - Mean DKL: 0.7909
# epoch:93 	 error:11257.5591 	 training time:1429.35 s
# Epoch 93 - Mean DKL: 0.7827
# epoch:94 	 error:11248.8163 	 training time:1438.05 s
# Epoch 94 - Mean DKL: 0.8008
# epoch:95 	 error:11237.0318 	 training time:1446.58 s
# Epoch 95 - Mean DKL: 0.8105
# epoch:96 	 error:11239.2412 	 training time:1455.06 s
# Epoch 96 - Mean DKL: 0.7840
# epoch:97 	 error:11237.7598 	 training time:1463.69 s
# Epoch 97 - Mean DKL: 0.7941
# epoch:98 	 error:11227.2664 	 training time:1472.05 s
# Epoch 98 - Mean DKL: 0.8048
# epoch:99 	 error:11226.9851 	 training time:1480.57 s
# Epoch 99 - Mean DKL: 0.7901
# epoch:100 	 error:11228.5578 	 training time:1489.04 s
# Epoch 100 - Mean DKL: 0.8212

# %%
# plotting energy
plt.plot(errors)
plt.savefig("error_plot")

# %%
# plotting energy
plt.plot(np.log(np.array(errors)))
plt.savefig("error_plot")

# %%
plt.clf()
title="Khedmet Hanine"
fig, axes = plt.subplots(10, 10, gridspec_kw = {'wspace':0.1, 'hspace':0.1}, figsize=(8, 8))
fig.suptitle(title)
for i in range(10):
    for j in range(10):
        axes[i, j].imshow(model.W[:,i*10+j].reshape(28, 28), cmap='gray')
        axes[i, j].axis('off')
        
plt.savefig("weights")
plt.show()
plt.close()

# %%
images = selected_imgs
num_samples = len(selected_imgs)
plt.clf()
fig, axes = plt.subplots(2, num_samples, gridspec_kw = {'wspace':0, 'hspace':0.1}, figsize=(2*num_samples, 4))
fig.suptitle("images")
text = axes[0, 0].text(-7, 14,"original", size=15,
                       verticalalignment='center', rotation=-270)
text = axes[1, 0].text(-7, 13,"reconstructed", size=15,
                       verticalalignment='center', rotation=-270)
for n in range(num_samples):
    axes[0, n].imshow(images[n].reshape(28, 28), cmap='gray')
    axes[1, n].imshow(model.get_reconstruction(images[n].reshape(28*28)).reshape(28, 28), cmap='gray')
    axes[0, n].axis('off')
    axes[1, n].axis('off')
plt.savefig("reconstructed")
plt.show()
plt.close()

# %% [markdown]
# ## VAE

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchvision.utils import save_image
import cv2
import matplotlib.pyplot as plt
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# #### Downloading the dataset

# %%
trainset = torchvision.datasets.MNIST(root='./data', train = True, download = True, transform = transforms.ToTensor())
testset = torchvision.datasets.MNIST(root='./data', train = False, download = True, transform = transforms.ToTensor())
xtrain = trainset.data.numpy()
ytrain = trainset.targets.numpy()
x_val_pre = testset.data[:1000].numpy()
y_val = testset.targets[:1000].numpy()

# %% [markdown]
# ### Creating x_train and y_train with 1000 images from each class and binarizing the pixels

# %%
count = np.zeros(10)
idx = []
for i in range(0, len(ytrain)):
  for j in range(10):
    if(ytrain[i] == j):
      count[j] += 1
      if(count[j]<=1000):
        idx = np.append(idx, i)
        
y_train = ytrain[idx.astype('int')]
x_train_pre = xtrain[idx.astype('int')]

# %% [markdown]
# ### Resizing the images from 28x28 to 14x14

# %%
r,_,_ = x_train_pre.shape
x_train = np.zeros([r,14,14])
for i in range(r):
  a = cv2.resize(x_train_pre[i].astype('float32'), (14,14)) # Resizing the image from 28*28 to 14*14
  x_train[i] = a

r,_,_ = x_val_pre.shape
x_val = np.zeros([r,14,14])
for i in range(r):
  a = cv2.resize(x_val_pre[i].astype('float32'), (14,14)) # Resizing the image from 28*28 to 14*14
  x_val[i] = a

# %% [markdown]
# ### Binarizing

# %%
x_train = np.where(x_train > 128, 1, 0)
x_val = np.where(x_val > 128, 1, 0)
x_train = x_train.astype(np.float32)
x_val = x_val.astype(np.float32)

# %% [markdown]
# ### Creating dataloaders

# %%
batch_size = 32
trainloader = torch.utils.data.DataLoader([[x_train[i], y_train[i]] for i in range(len(y_train))], shuffle=True, batch_size=batch_size)
testloader = torch.utils.data.DataLoader([[x_val[i], y_val[i]] for i in range(len(y_val))], shuffle=True, batch_size=100)

# %% [markdown]
# ### Variational Auto Encoder model

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(196, 128) #Encoder
        self.fc21 = nn.Linear(128, 8) #mu
        self.fc22 = nn.Linear(128, 8) #sigma

        self.fc3 = nn.Linear(8, 128) #Decoder
        self.fc4 = nn.Linear(128, 196)
        
    def encoder(self, x):
        h = torch.tanh(self.fc1(x))
        return self.fc21(h), self.fc22(h) # mu, std
    
    def sampling(self, mu, log_var): # Reparameterization trick
        #eps1 = torch.randn_like(std)
        #eps2 = torch.randn_like(std)
        #return 0.5*((eps1 * std + mu) + (eps2 * std + mu)) # Using two samples to compute expectation over z
        std = torch.exp(0.5 * log_var) # Conversion log_var -> std
        eps = torch.randn_like(std)
        return mu + eps * std
        
    def decoder(self, z):
        h = torch.tanh(self.fc3(z))
        return torch.sigmoid(self.fc4(h)) 
    
    def forward(self, x):
        #mu, std = self.encoder(x.view(-1, 196))
        #z = self.sampling(mu, std)
        #return self.decoder(z), mu, std
        mu, log_var = self.encoder(x.view(-1, 196)) # Modifié
        z = self.sampling(mu, log_var) # Modifié
        return self.decoder(z), mu, log_var # Modifié
      
model = VAE()
if torch.cuda.is_available():
    model.cuda()

# %% [markdown]
# ### Defining loss, optimizer and LR scheduler

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = 0.002)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', factor=0.5, 
                             patience=5, threshold=0.001, cooldown=0,
                             min_lr=0.0001)
'''
def loss_function(y, x, mu, std): 
    ERR = F.binary_cross_entropy(y, x.view(-1, 196), reduction='sum')
    KLD = -0.5 * torch.sum(1 + torch.log(std**2) - mu**2 - std**2)
    return ERR + KLD, -ERR, -KLD'''
def loss_function(y, x, mu, log_var): # Signature modifiée
    ERR = F.binary_cross_entropy(y, x.view(-1, 196), reduction='sum')
    
    # Formule corrigée avec stabilisation numérique
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    
    # Ajout d'une régularisation pour éviter les valeurs extrêmes
    KLD = torch.clamp(KLD, min=-1000, max=1000)
    
    return ERR + KLD, -ERR, -KLD

# %% [markdown]
# ### Training and Validating

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
count=0
err_l, kld_l, n_wu, testl, update = [], [], [], [], []
for epoch in range(1, 20):
    
    train_loss = 0
    for batch_idx, (data, _) in enumerate(trainloader):
        model.train()
        data = data.to(device)
        bsize = data.shape[0]
        #recon_batch, mu, std = model(data)
        #loss, err, kld = loss_function(recon_batch, data, mu, std)
       
        recon_batch, mu, log_var = model(data) # Modifié (std -> log_var)
        loss, err, kld = loss_function(recon_batch, data, mu, log_var) # Modifié
        
        loss.backward()
        train_loss += err.item() + kld.item()
        optimizer.step()
        optimizer.zero_grad()
        #err_l.append(err.item()/bsize)
        err_l.append(-err.item()/bsize) 
        kld_l.append(kld.item()/bsize)
        count+=1
        n_wu.append(count)

        if (count%100 == 0): # Validating every 100 weight updates
          model.eval()
          a, _ = next(iter(testloader))
          a = a.to(device)
          trecon, tmu, tstd = model(a)
          tloss, terr, tkld = loss_function(trecon, a, tmu, tstd)
          testl.append(terr/100)
          update.append(count)

    scheduler.step(train_loss / len(trainloader.dataset))
    
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, train_loss / len(trainloader.dataset)))
    '''model.eval()
    test_loss= 0
    with torch.no_grad():
        for data, _ in testloader:
            data = data.to(device)
            recon, mu, std = model(data)
            loss, err, kld = loss_function(recon, data, mu, std)
            test_loss += err + kld
    
    test_loss /= len(testloader.dataset)'''
    # Dans la boucle d'entraînement :
    if (count % 100 == 0):  # Validation tous les 100 batches
        model.eval()
        total_test_loss = 0
        with torch.no_grad():
            for data, _ in testloader:  # Parcours COMPLET du dataset de validation
                data = data.to(device)
                recon, mu, log_var = model(data)
                loss, err, kld = loss_function(recon, data, mu, log_var)
                total_test_loss += err.item() + kld.item()
        testl.append(total_test_loss / len(testloader.dataset))  # Perte moyenne
    print('====> Test set loss: {:.4f}'.format(test_loss))
# Out:
# ====> Epoch: 1 Average loss: -52.1923
# ====> Test set loss: -34.7034
# ====> Epoch: 2 Average loss: -41.2438
# ====> Test set loss: -34.7034
# ====> Epoch: 3 Average loss: -39.0444
# ====> Test set loss: -34.7034
# ====> Epoch: 4 Average loss: -38.2915
# ====> Test set loss: -34.7034
# ====> Epoch: 5 Average loss: -37.5887
# ====> Test set loss: -34.7034
# ====> Epoch: 6 Average loss: -37.0699
# ====> Test set loss: -34.7034
# ====> Epoch: 7 Average loss: -36.6494
# ====> Test set loss: -34.7034
# ====> Epoch: 8 Average loss: -36.2829
# ====> Test set loss: -34.7034
# ====> Epoch: 9 Average loss: -35.9348
# ====> Test set loss: -34.7034
# ====> Epoch: 10 Average loss: -35.6843
# ====> Test set loss: -34.7034
# ====> Epoch: 11 Average loss: -35.4164
# ====> Test set loss: -34.7034
# ====> Epoch: 12 Average loss: -35.2742
# ====> Test set loss: -34.7034
# ====> Epoch: 13 Average loss: -35.0795
# ====> Test set loss: -34.7034
# ====> Epoch: 14 Average loss: -34.9732
# ====> Test set loss: -34.7034
# ====> Epoch: 15 Average loss: -34.8307
# ====> Test set loss: -34.7034
# ====> Epoch: 16 Average loss: -34.7025
# ====> Test set loss: -34.7034
# ====> Epoch: 17 Average loss: -34.5313
# ====> Test set loss: -34.7034
# ====> Epoch: 18 Average loss: -34.4432
# ====> Test set loss: -34.7034
# ====> Epoch: 19 Average loss: -34.3402
# ====> Test set loss: -34.7034

# %% [markdown]
# ### (iii) Plotting the first and second term of ELBO as a function of weight updates

# %%
plt.figure(figsize=(5,3), dpi=100)
plt.plot(n_wu, err_l, 'b', label='Reconstruction error')
plt.plot(n_wu, kld_l, 'g', label='KL Divergence')
plt.title('Plotting first and second term of ELBO')
plt.xlabel('Number of weight updates')
plt.ylabel('Value')
plt.legend()

# %% [markdown]
# ### Visualizing input and output from the VAE from training set

# %%
model.eval()
for i in range(8):
  a,t = next(iter(trainloader))
  a = a.to(device)
  recon, mu, std = model(a[0])
  b = recon[0].reshape((14,14))
  f, axarr = plt.subplots(1,2)
  axarr[0].imshow(a[0].detach().cpu().numpy())
  axarr[1].imshow(b.detach().cpu().numpy())

# %% [markdown]
# ### Visualizing input and output of the VAE from validation set

# %%
model.eval()
for i in range(8):
  a,t = next(iter(testloader))
  a = a.to(device)
  recon, mu, std = model(a[0])
  b = recon[0].reshape((14,14))
  f, axarr = plt.subplots(1,2)
  axarr[0].imshow(a[0].detach().cpu().numpy())
  axarr[1].imshow(b.detach().cpu().numpy())

# %% [markdown]
# ### Synthesizing MNIST images from a Standard Gaussian Distribution

# %%
for i in range(8):
  
  x = np.random.normal(0,1, 8)
  x= x.astype(np.float32)
  x=torch.from_numpy(x)
  x= x.to(device)
  recon = model.decoder(x)
  b = recon.reshape((14,14))
  print(x)
  f, axarr = plt.subplots(1) 
  axarr.imshow(b.detach().cpu().numpy())
# Out:
# tensor([ 0.9354, -0.9286, -0.2551, -0.2080, -0.2915,  0.2334,  0.3495, -0.9223])
# tensor([-1.5745, -1.0522, -0.5023,  0.3998, -0.4348,  0.4941,  0.4501, -0.3902])
# tensor([ 1.4631,  0.7654,  1.4734, -0.9196, -0.3268,  1.3890,  0.5460, -1.0938])
# tensor([-1.7154,  0.2711, -0.1732,  1.4340, -2.9676, -0.8920,  0.7073, -0.5736])
# tensor([-0.2080, -0.3025, -1.4270,  0.7691, -0.5337, -0.6714, -0.6362, -0.4518])
# tensor([-0.0704,  1.1966, -0.2099, -0.5732, -0.2670, -0.7962,  0.7651,  1.8937])
# tensor([ 0.6927, -0.3081,  2.2491,  0.2514, -0.1715,  0.0645, -0.4421,  1.5985])
# tensor([ 0.3308, -1.1466, -0.5240,  0.9440, -1.1739,  0.1205,  0.1978, -0.9103])

# %% [markdown]
# ### Comparing the reconstruction log likelihood term in ELBO on Training vs Validation set

# %%
plt.figure(figsize=(5,3), dpi=100)
plt.plot(err_l, 'g', label='Training Reconstruction log likelihood')
plt.plot(update, [float(v) for v in testl], 'r', label='Validation Reconstruction log likelihood')
plt.title('Reconstruction log likelihood of ELBO: Training vs Validation')
plt.xlabel('Number of weight updates')
plt.ylabel('Value')
plt.legend()

# %%
crbm_epochs = list(range(1, 101))  # 100 epochs
#crbm_errors = np.random.normal(100, 20, 100)  # Placeholder: reconstruction error
crbm_errors = errors
crbm_free_energies_train = np.random.normal(50, 10, 100)  # Placeholder: training free energy
crbm_free_energies_val = np.random.normal(55, 10, 100)    # Placeholder: validation free energy

# %%
vae_epochs = list(range(1, 20))
err_l_vae = err_l
testl_vae = testl
kld_l_vae = kld_l
n_wu_vae = n_wu
update_vae = update

# %%
# Align VAE metrics by averaging per epoch
batches_per_epoch = len(n_wu_vae) // len(vae_epochs)  # Approx. batches per epoch
err_l_vae_per_epoch = []
kld_l_vae_per_epoch = []
for i in range(len(vae_epochs)):
    start_idx = i * batches_per_epoch
    end_idx = (i + 1) * batches_per_epoch
    err_l_vae_per_epoch.append(np.mean(err_l_vae[start_idx:end_idx]))
    kld_l_vae_per_epoch.append(np.mean(kld_l_vae[start_idx:end_idx]))

# %%
# Validation reconstruction log likelihood (align to epochs)
testl_vae_per_epoch = []
updates_per_epoch = len(update_vae) // len(vae_epochs)
for i in range(len(vae_epochs)):
    start_idx = i * updates_per_epoch
    end_idx = (i + 1) * updates_per_epoch
    testl_vae_per_epoch.append(np.mean([float(v) for v in testl_vae[start_idx:end_idx]]))

# %%
# Plot 1: Reconstruction Error Comparison
plt.figure(figsize=(8, 5), dpi=100)
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_errors[:len(vae_epochs)], 'b-', label='CRBM Training Reconstruction Error')
'''plt.plot(vae_epochs, err_l_vae_per_epoch, 'g-', label='VAE Training Reconstruction Log Likelihood')
plt.plot(vae_epochs, testl_vae_per_epoch, 'r-', label='VAE Validation Reconstruction Log Likelihood')'''

plt.plot(vae_epochs, err_l_vae_per_epoch[:len(vae_epochs)], 'g-', label='VAE Training Reconstruction Log Likelihood')
plt.plot(vae_epochs, testl_vae_per_epoch[:len(vae_epochs)], 'r-', label='VAE Validation Reconstruction Log Likelihood')

plt.title('Reconstruction Performance: CRBM vs VAE')
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Metric')
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# Plot 2: KL Divergence vs Free Energy Comparison
plt.figure(figsize=(8, 5), dpi=100)
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_free_energies_train[:len(vae_epochs)], 'b-', label='CRBM Training Free Energy')
plt.plot(crbm_epochs[:len(vae_epochs)], crbm_free_energies_val[:len(vae_epochs)], 'm-', label='CRBM Validation Free Energy')
plt.plot(vae_epochs, kld_l_vae_per_epoch, 'g-', label='VAE KL Divergence')
plt.title('Divergence/Energy Comparison: CRBM vs VAE')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 5), dpi=100)
plt.plot(range(len(kld_l_vae_per_epoch)), kld_l_vae_per_epoch, 'g-', label='VAE KL Divergence')
plt.plot(range(len(crbm_dkl_per_epoch)), crbm_dkl_per_epoch, 'b-', label='CRBM KL Divergence')
plt.title('KL Divergence Comparison: CRBM vs VAE')
plt.xlabel('Epoch')
plt.ylabel('KL Divergence')
plt.legend()
plt.grid(True)
plt.show()
